# %% [markdown]
# **Навигация по уроку**
#
# 1. [Введение в Python. Синтаксис](https://colab.research.google.com/drive/1YBLgd6tZYlkhwpnEc4IM8tVnewLUnlUO#scrollTo=yqZjRAldfz_L)
# 2. [Практика](https://colab.research.google.com/drive/1m-Ph90c-9S_gZchdG1ARoY2YjMTryKkl#scrollTo=UdxWiGmA63K2)
# 3. Домашняя работа

# %% [markdown]
# В домашней работе необходимо, используя знания теоретической части занятия и полученные практические навыки, решить, представленные ниже задачи. Для этого необходимо скопировать Блокнот (см. раздел 1.1.), решить в нем все задач, открыть общий доступ к Блокноту ((см. раздел 1.1.) и отправить ссылку на Блокнот куратору на проверку. Желаем удачи!

# %% [markdown]
# ## Задача 1. Приветствие.

# %% [markdown]
# **Условие.** Напишите программу, запрашивающую у пользователя его имя. В ответ
# на ввод на экране должно появиться приветствие с обращением по имени,
# введенному с клавиатуры ранее.

# %%
#Напишите свое решение
name = input('Введите ваше Имя: ')
print(f'Добро пожаловать: {name}')
# Out:
# Введите ваше Имя: Илья Куликов
# Добро пожаловать: Илья Куликов

# %% [markdown]
# ## Задача 2. Сувениры и безделушки.

# %% [markdown]
# **Условие.** Интернет-магазин занимается продажей различных сувениров и безделушек. Каждый сувенир весит 75 г, а безделушка – 112 г. Напишите программу, запрашивающую у пользователя количество тех и других покупок,
# после чего выведите на экран общий вес посылки.

# %%
#Напишите свое решение
suv_ves = 75
bez_ves = 112
a = int(input('Введите количество сувениров: '))
b = int(input('Введите количество безделушек: '))
sum = float(suv_ves * a + bez_ves * b) / 1000
if sum > 1:
  print(f'общий вес посылки: {sum:.3f} кг')
else:
  print(f'общий вес посылки: {sum:.3f} гр')
# Out:
# Введите количество сувениров: 10
# Введите количество безделушек: 12
# общий вес посылки: 2.094 кг

# %% [markdown]
# ## Задача 3. Сложные проценты

# %% [markdown]
# **Условие.** Представьте, что вы открыли в банке сберегательный счет под 4 % годовых. Проценты банк рассчитывает в конце года и добавляет к сумме счета.
# Напишите программу, которая запрашивает у пользователя сумму первоначального депозита, после чего рассчитывает и выводит на экран сумму
# на счету в конце первого, второго и третьего годов. Все суммы должны
# быть округлены до двух знаков после запятой.

# %%
#Напишите свое решение
f_price = float(input('Введите сумму превоначального взноса: '))
year1 = f_price + f_price * 0.04
year2 = year1 + year1 * 0.04
year3 = year2 + year2 * 0.04
print(f'На счету будет: \n 1 год: {year1:.2f} \n 2 год: {year2:.2f} \n 3 год: {year3:.2f}')
# Out:
# Введите сумму превоначального взноса: 104
# На счету будет:
#  1 год: 108.16
#  2 год: 112.49
#  3 год: 116.99

# %% [markdown]
# ## Задача 4. Арифметика

# %% [markdown]
# **Условие.** Создайте программу, которая запрашивает у пользователя два целых числа a и b, после чего выводит на экран результаты следующих математических операций:
# * сумма a и b;
# * разница между a и b;
# * произведение a и b;
# * частное от деления a на b;
# * остаток от деления a на b;
# * десятичный логарифм числа a;
# * результат возведения числа a в степень b.

# %%
#Напишите свое решение
import math
a = int(input('Введите число а: '))
b = int(input('Введите число b: '))

log10 = math.log10(a)

print('сумма a и b =', a + b)
print('разница между a и b =', a - b)
print('произведение a и b =', a * b)
print('частное от деления a на b =', a / b)
print('остаток от деления a на b =', a % b)
print(f'десятичный логарифм числа a = {log10}')
print('результат возведения числа a в степень b =', a ** b)
# Out:
# Введите число а: 7
# Введите число b: 4
# сумма a и b = 11
# разница между a и b = 3
# произведение a и b = 28
# частное от деления a на b = 1.75
# остаток от деления a на b = 3
# десятичный логарифм числа a = 0.8450980400142568
# результат возведения числа a в степень b = 2401

# %% [markdown]
# ## Задача 5. Размен

# %% [markdown]
# **Условие.** Представьте, что вы пишете программное обеспечение для автоматической кассы в  магазине самообслуживания. Одной из функций, заложенных в кассу, должен быть расчет сдачи в случае оплаты покупателем наличными.
# Напишите программу, которая будет запрашивать у пользователя сумму сдачи в копейках. После этого она должна рассчитать и вывести на экран, сколько и каких монет потребуется для выдачи указанной суммы, при условии что должно быть задействовано минимально возможное количество монет. Допустим, у нас есть в распоряжении монеты достоинством в 1, 5, 10, 50 копеек, а также в 1, 2 и 5 рублей.

# %%
#Напишите свое решение
def calc(n):
    coins = [500, 200, 100, 50, 10, 5, 1]
    list = {}
    for coin in coins:
        if n >= coin:
            co = n // coin
            list[coin] = co
            n = n % coin
    return list
def sdacha():
    summa = float(input('Введите сумму сдачи: '))
    sum = summa * 100
    change = calc(sum)
    print('Ваша сдача:')
    for coin, count in change.items():
        if count > 0:
            print(f'{count:.0f} Монет(а) номиналом {coin/100:.2f} руб.')

sdacha()
# Out:
# Введите сумму сдачи: 1000.59
# Ваша сдача:
# 200 Монет(а) номиналом 5.00 руб.
# 1 Монет(а) номиналом 0.50 руб.
# 1 Монет(а) номиналом 0.05 руб.
# 4 Монет(а) номиналом 0.01 руб.

# %% [markdown]
# ## Задача 6. Вчерашний хлеб

# %% [markdown]
# **Условие.** Пекарня продает хлеб по 49 рублей за буханку. Скидка на вчерашний хлеб составляет 60 %. Напишите программу, которая будет запрашивать у пользователя количество приобретенных вчерашних буханок хлеба. В вывод на экран должны быть включены обычная цена за буханку, цена со скидкой и общая стоимость приобретенного хлеба. Все значения должны быть выведены на отдельных строках с соответствующими описаниями. Используйте для вывода формат с двумя знаками после запятой и 5-ю знакоместами.

# %%
#Напишите свое решение
quantity = int(input('Введите количество буханок: '))
price1 = 49
price1_s = price1 - (price1 * 0.60)
skidka1 = (quantity * price1) * 0.60

total_price = quantity * price1
total_price_s = total_price - skidka1

print('%29s %7.2f' % ('Цена за 1 буханку:', price1))
print('Цена за 1 буханку со скидкой:%8.2f' % price1_s)
print('%29s %7d' % ('Общее количество:', quantity))
print('%29s %7.2f' % ('Цена за товар:', total_price))
print('%29s %7.2f' % ('Скидка:', skidka1))
print('%29s %7.2f' % ('Цена за товар со скидкой:', total_price_s))
print()
print()
price_f = 'Цена за 1 буханку:'
price_f_s = 'Цена за 1 буханку со сккидкой:'

print(f'{price_f:>30}{price1:>7.2f}')
print(f'{price_f_s:>30}{price1_s:>7.2f}')
print(f"{f'Общее количество:{quantity:7}':>37}")
print(f"{f'Цена за товар:{total_price:7.2f}':>37}")
print(f"{f'Скидка:{skidka1:7.2f}':>37}")
print(f"{f'Цена за товар со скидкой:{total_price_s:7.2f}':>37}")
# Out:
# Введите количество буханок: 12
#            Цена за 1 буханку:   49.00
# Цена за 1 буханку со скидкой:   19.60
#             Общее количество:      12
#                Цена за товар:  588.00
#                       Скидка:  352.80
#     Цена за товар со скидкой:  235.20
#
#
#             Цена за 1 буханку:  49.00
# Цена за 1 буханку со сккидкой:  19.60
#              Общее количество:     12
#                 Цена за товар: 588.00
#                        Скидка: 352.80
#      Цена за товар со скидкой: 235.20
